# %% [markdown]
# # Debugging

# %%
library(phyloseq)

# %%
?plot_ordination

# %%
data(GlobalPatterns)
GP = prune_taxa(names(sort(taxa_sums(GlobalPatterns), TRUE)[1:50]), GlobalPatterns)
gp_bray_pcoa = ordinate(GP, "CCA", "bray")
plot_ordination(GP, gp_bray_pcoa, "samples", color="SampleType")
# Out:
# plot without title

# %%
plot(1,1)
# Out:
# plot without title

# %%
library(ggplot2)

# %%
ggplot2::ggplot(iris, aes(x = Petal.Length,y = Petal.Width)) + geom_point()
# Out:
# plot without title
